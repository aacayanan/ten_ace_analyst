# %%
# import libraries
import pandas as pd
import requests
pd.set_option('display.max_columns', None)  # so we can see all columns in a wide DataFrame
import time
import numpy as np

# %%
# set the URLs for the dataframes
stats_23 = 'https://www.atptour.com/en/-/www/individualmatchstats/2023/all/all/Aces/percentage/desc/1/1000'
stats_24 = 'https://www.atptour.com/en/-/www/individualmatchstats/2024/all/all/Aces/percentage/desc/1/1000'

# %%
# get the stats api request
r23 = requests.get(url=stats_23).json()
r24 = requests.get(url=stats_24).json()

# %%
# put it to a dataframe and see the data
df23 = pd.DataFrame(r23['StatsList'])
df24 = pd.DataFrame(r24['StatsList'])
df23
# Out:
#     Number PlayerId     LastName  FirstName NatlId  \
# 0    1,031     HB71      Hurkacz     Hubert    POL
# 1      692     FB98        Fritz     Taylor    USA
# 2      616     RE44       Rublev     Andrey    RUS
# 3      613     Z355       Zverev  Alexander    GER
# 4      547     TE51    Tsitsipas   Stefanos    GRE
# ..     ...      ...          ...        ...    ...
# 195     17     MH30      Millman       John    AUS
# 196     17     T0AP        Tseng  Chun-Hsin    TPE
# 197     16     HD68       Harris      Billy    GBR
# 198     16     K0DP      Krutykh    Oleksii    UKR
# 199     16     D0CG  Diaz Acosta    Facundo    ARG
#
#                PlayerHeadshotImageCmsUrl  \
# 0    /-/media/alias/player-headshot/hb71
# 1    /-/media/alias/player-headshot/fb98
# 2    /-/media/alias/player-headshot/re44
# 3    /-/media/alias/player-headshot/z355
# 4    /-/media/alias/player-headshot/te51
# ..                                   ...
# 195  /-/media/alias/player-headshot/mh30
# 196  /-/media/alias/player-headshot/t0ap
# 197  /-/media/alias/player-headshot/hd68
# 198  /-/media/alias/player-headshot/k0dp
# 199  /-/media/alias/player-headshot/d0cg
#
#                   PlayerScRelativeUrlPlayerProfile  \
# 0         /en/players/hubert-hurkacz/hb71/overview
# 1           /en/players/taylor-fritz/fb98/overview
# 2          /en/players/andrey-rublev/re44/overview
# 3       /en/players/alexander-zverev/z355/overview
# 4     /en/players/stefanos-tsitsipas/te51/overview
# ..                                             ...
# 195         /en/players/john-millman/mh30/overview
# 196      /en/players/chun-hsin-tseng/t0ap/overview
# 197         /en/players/billy-harris/hd68/overview
# 198      /en/players/oleksii-krutykh/k0dp/overview
# 199  /en/players/facundo-diaz-acosta/d0cg/overview
#
#     PlayerScRelativeUrlPlayerCountryFlag Percentage  Matches
# 0       /en/~/media/images/flags/pol.svg      0.00%       69
# 1       /en/~/media/images/flags/usa.svg      0.00%       77
# 2       /en/~/media/images/flags/rus.svg      0.00%       82
# 3       /en/~/media/images/flags/ger.svg      0.00%       80
# 4       /en/~/media/images/flags/gre.svg      0.00%       71
# ..                                   ...        ...      ...
# 195     /en/~/media/images/flags/aus.svg      0.00%        4
# 196     /en/~/media/images/flags/tpe.svg      0.00%        6
# 197     /en/~/media/images/flags/gbr.svg      0.00%        2
# 198     /en/~/media/images/flags/ukr.svg      0.00%        3
# 199     /en/~/media/images/flags/arg.svg      0.00%        6
#
# [200 rows x 10 columns]

# %%
# remove specific columns from both dataframes
columns_to_remove = ['PlayerHeadshotImageCmsUrl', 'PlayerScRelativeUrlPlayerProfile', 'PlayerScRelativeUrlPlayerCountryFlag']
df_cleaned_23 = df23.drop(columns=columns_to_remove)
df_cleaned_24 = df24.drop(columns=columns_to_remove)

# %%
# see cleaned dataframes
df_cleaned_23
# Out:
#     Number PlayerId     LastName  FirstName NatlId Percentage  Matches
# 0    1,031     HB71      Hurkacz     Hubert    POL      0.00%       69
# 1      692     FB98        Fritz     Taylor    USA      0.00%       77
# 2      616     RE44       Rublev     Andrey    RUS      0.00%       82
# 3      613     Z355       Zverev  Alexander    GER      0.00%       80
# 4      547     TE51    Tsitsipas   Stefanos    GRE      0.00%       71
# ..     ...      ...          ...        ...    ...        ...      ...
# 195     17     MH30      Millman       John    AUS      0.00%        4
# 196     17     T0AP        Tseng  Chun-Hsin    TPE      0.00%        6
# 197     16     HD68       Harris      Billy    GBR      0.00%        2
# 198     16     K0DP      Krutykh    Oleksii    UKR      0.00%        3
# 199     16     D0CG  Diaz Acosta    Facundo    ARG      0.00%        6
#
# [200 rows x 7 columns]

# %%
# concatenate the dataframe to be organized by playerid
df_combined = pd.merge(df_cleaned_23, df_cleaned_24, on='PlayerId', how='outer', suffixes=('_23', '_24'))

# %%
# see the concatenated dataframe
df_combined
# Out:
#     Number_23 PlayerId      LastName_23 FirstName_23 NatlId_23 Percentage_23  \
# 0         NaN     A0CJ              NaN          NaN       NaN           NaN
# 1         302     A0E2          Alcaraz       Carlos       ESP         0.00%
# 2         167     A0FC          Arnaldi       Matteo       ITA         0.00%
# 3         NaN     A0G8              NaN          NaN       NaN           NaN
# 4          28     A0GC           Atmane      Terence       FRA         0.00%
# ..        ...      ...              ...          ...       ...           ...
# 246        33     Z09Z         Zhukayev       Beibit       KAZ         0.00%
# 247        22     Z0A1         Zeppieri       Giulio       ITA         0.00%
# 248       613     Z355           Zverev    Alexander       GER         0.00%
# 249       213     Z371            Zhang      Zhizhen       CHN         0.00%
# 250        73     Z419  Zapata Miralles      Bernabe       ESP         0.00%
#
#      Matches_23 Number_24      LastName_24 FirstName_24 NatlId_24  \
# 0           NaN         0        Ajdukovic         Duje       CRO
# 1          77.0        37          Alcaraz       Carlos       ESP
# 2          31.0        98          Arnaldi       Matteo       ITA
# 3           NaN         0          Elsayed          Amr       EGY
# 4           4.0        25           Atmane      Terence       FRA
# ..          ...       ...              ...          ...       ...
# 246         3.0       NaN              NaN          NaN       NaN
# 247         4.0        49         Zeppieri       Giulio       ITA
# 248        80.0       147           Zverev    Alexander       GER
# 249        36.0        55            Zhang      Zhizhen       CHN
# 250        41.0        10  Zapata Miralles      Bernabe       ESP
#
#     Percentage_24  Matches_24
# 0           0.00%         0.0
# 1           0.00%         9.0
# 2           0.00%        10.0
# 3           0.00%         0.0
# 4           0.00%         2.0
# ..            ...         ...
# 246           NaN         NaN
# 247         0.00%         4.0
# 248         0.00%        14.0
# 249         0.00%        11.0
# 250         0.00%         7.0
#
# [251 rows x 13 columns]
