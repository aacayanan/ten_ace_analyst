# %%
import pandas as pd
import requests
pd.set_option('display.max_columns', None)  # so we can see all columns in a wide DataFrame
import time
import numpy as np

# %%
stats_24 = 'https://www.atptour.com/en/-/www/individualmatchstats/2024/all/all/Aces/percentage/desc/1/1000'
stats_23 = 'https://www.atptour.com/en/-/www/individualmatchstats/2023/all/all/Aces/percentage/desc/1/1000'

# %%
r24 = requests.get(url=stats_24).json()
r23 = requests.get(url=stats_23).json()

# %%
header_tables24 = r24

# %%
header_tables24['Headers']
# Out:
# [{'Identifier': 'Player', 'Value': 'Player'},
#  {'Identifier': 'Number', 'Value': 'Number'},
#  {'Identifier': 'Matches', 'Value': 'Matches'}]

# %%
pd.DataFrame(r24['StatsList'])
# Out:
#     Number PlayerId  LastName  FirstName NatlId  \
# 0      150     HB71   Hurkacz     Hubert    POL
# 1      128     Z355    Zverev  Alexander    GER
# 2      118     BK92    Bublik  Alexander    KAZ
# 3      101     R0DG      Rune     Holger    DEN
# 4       95     RE44    Rublev     Andrey    RUS
# ..     ...      ...       ...        ...    ...
# 173      0     V993      Vasa       Eero    FIN
# 174      0     V0AM  Virtanen       Otto    FIN
# 175      0     W857        Wu   Tung-Lin    TPE
# 176      0     Y218      Ymer      Elias    SWE
# 177      0     S0GD   Svrcina    Dalibor    CZE
#
#                PlayerHeadshotImageCmsUrl  \
# 0    /-/media/alias/player-headshot/hb71
# 1    /-/media/alias/player-headshot/z355
# 2    /-/media/alias/player-headshot/bk92
# 3    /-/media/alias/player-headshot/r0dg
# 4    /-/media/alias/player-headshot/re44
# ..                                   ...
# 173  /-/media/alias/player-headshot/v993
# 174  /-/media/alias/player-headshot/v0am
# 175  /-/media/alias/player-headshot/w857
# 176  /-/media/alias/player-headshot/y218
# 177  /-/media/alias/player-headshot/s0gd
#
#                PlayerScRelativeUrlPlayerProfile  \
# 0      /en/players/hubert-hurkacz/hb71/overview
# 1    /en/players/alexander-zverev/z355/overview
# 2    /en/players/alexander-bublik/bk92/overview
# 3         /en/players/holger-rune/r0dg/overview
# 4       /en/players/andrey-rublev/re44/overview
# ..                                          ...
# 173         /en/players/eero-vasa/v993/overview
# 174     /en/players/otto-virtanen/v0am/overview
# 175       /en/players/tung-lin-wu/w857/overview
# 176        /en/players/elias-ymer/y218/overview
# 177   /en/players/dalibor-svrcina/s0gd/overview
#
#     PlayerScRelativeUrlPlayerCountryFlag Percentage  Matches
# 0       /en/~/media/images/flags/pol.svg      0.00%       10
# 1       /en/~/media/images/flags/ger.svg      0.00%       11
# 2       /en/~/media/images/flags/kaz.svg      0.00%        9
# 3       /en/~/media/images/flags/den.svg      0.00%       10
# 4       /en/~/media/images/flags/rus.svg      0.00%        9
# ..                                   ...        ...      ...
# 173     /en/~/media/images/flags/fin.svg      0.00%        0
# 174     /en/~/media/images/flags/fin.svg      0.00%        0
# 175     /en/~/media/images/flags/tpe.svg      0.00%        0
# 176     /en/~/media/images/flags/swe.svg      0.00%        0
# 177     /en/~/media/images/flags/cze.svg      0.00%        1
#
# [178 rows x 10 columns]
